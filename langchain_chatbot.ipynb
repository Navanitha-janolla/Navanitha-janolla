# %% [markdown]
# <a href="https://colab.research.google.com/github/Navanitha-janolla/Navanitha-janolla/blob/main/langchain_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade langchain openai -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 8.9 MB/s eta 0:00:00

# %%
# !pip install sentence_transformers -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.0 MB/s eta 0:00:00

# %%
# !pip install unstructured -q
# !pip install unstructured[local-interface] -q
# !pip install detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.4 MB/s eta 0:00:00
# ...
# WARNING: unstructured 0.16.23 does not provide the extra 'local-interface'
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.6 [186 kB]
# Fetched 186 kB in 0s (756 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.6_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.6) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.6) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 31.8 MB/s eta 0:00:00
# ...

# %%
    # !mkdir ai_douc

# %%
# !pip install "unstructured[pdf]" -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 523.4/523.4 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 52.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 60.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.3 MB/s eta 0:00:00

# %%
from langchain.document_loaders import DirectoryLoader

directory = '/content/drive/MyDrive/ai douc'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# 2

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents,chunk_size=500,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 715

# %%
print(docs[8].page_content)
# Out:
# How to Cite While permission to reprint this publication is not necessary, the suggested citation is as follows: U.S. Department of Education, Office of Educational Technology, Artificial Intelligence and
#
# Future of Teaching and Learning: Insights and Recommendations, Washington, DC, 2023.
#
# This report is available at https://tech.ed.gov

# %%
from langchain.embeddings import SentenceTransformerEmbeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# <ipython-input-17-aebb89d36047>:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
query_result = embeddings.embed_query(docs[8].page_content)
len(query_result)
# Out:
# 384

# %%
# !pip install pinecone
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.4/421.4 kB 6.3 MB/s eta 0:00:00
# ...

# %%
# import pinecone
# from langchain.vectorstores import Pinecone
# pinecone_p=pinecone.pinecone(
#     api_key="pcsk_5HZssW_8aYPd1N1NwM5qaba8Lru66dMFWCcVGCorVUjPjuTkqCawNxCFygKUJznTsv15Xq",  # find at app.pinecone.io
#     environment="us-east-1"  # next to api key in console
# )
# index_name = "langchain-chatbot"
# index = Pinecone.from_documents(docs, embeddings, index_name=index_name)



# import pinecone

# # Create a Pinecone instance
# pc = pinecone.Pinecone(
#     api_key="pcsk_5HZssW_8aYPd1N1NwM5qaba8Lru66dMFWCcVGCorVUjPjuTkqCawNxCFygKUJznTsv15Xq"
# )

# # List available indexes
# print(pc.list_indexes().names())

# # Example: Creating an index if it doesn't exist
# if 'my_index' not in pc.list_indexes().names():
#     from pinecone import ServerlessSpec

#     pc.create_index(
#         name='langchain1',
#         dimension=384,  # Make sure this matches your embeddings
#         metric='euclidean',
#         spec=ServerlessSpec(
#             cloud='aws',
#             region='us-east-1'  # Adjust the region as per your account
#         )
#     )

# # Connecting to the index
# index = pc.Index("langchain1")


import pinecone

# Create a Pinecone instance
pc = pinecone.Pinecone(
    api_key="AIzaSyBVLQCgTbNqnkXy80iO_S6iZ3ed78jBHrc"
)

# List available indexes
print(pc.list_indexes().names())

# Example: Creating an index if it doesn't exist
# Check if the index exists before attempting to create it
if 'langchain1' not in pc.list_indexes().names():
    from pinecone import ServerlessSpec

    pc.create_index(
        name='langchain1',
        dimension=384,  # Make sure this matches your embeddings
        metric='euclidean',
        spec=ServerlessSpec(
            cloud='aws',
            region='us-east-1'  # Adjust the region as per your account
        )
    )
else:
    print("Index 'langchain1' already exists. Skipping creation.")

# Connecting to the index
index = pc.Index("langchain1")
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedException                     Traceback (most recent call last)
# <ipython-input-3-37fe22d8773a> in <cell line: 0>()
#      46
#      47 # List available indexes
# ---> 48 print(pc.list_indexes().names())
#      49
#      50 # Example: Creating an index if it doesn't exist
#
# /usr/local/lib/python3.11/dist-packages/pinecone/control/pinecone.py in list_indexes(self)
#     233
#     234     def list_indexes(self) -> IndexList:
# --> 235         response = self.index_api.list_indexes()
#     236         return IndexList(response)
#     237
#
# /usr/local/lib/python3.11/dist-packages/pinecone/openapi_support/endpoint.py in __call__(self, *args, **kwargs)
#     100
#     101         """
# --> 102         return self.callable(self, *args, **kwargs)
#     103
#     104     def call_with_http_info(self, **kwargs):
#
# ...

# %%
import pinecone

# Initialize Pinecone
pc = pinecone.Pinecone(api_key="pcsk_5HZssW_8aYPd1N1NwM5qaba8Lru66dMFWCcVGCorVUjPjuTkqCawNxCFygKUJznTsv15Xq")

# Connect to the existing index
index_name = "langchain-chatbot"
index = pc.Index(index_name)

# Get index statistics
stats = index.describe_index_stats()

# Print the total number of vectors
print(f"Total vectors in index: {stats['total_vector_count']}")
# Out:
# Total vectors in index: 0

# %%
def get_similiar_docs(query,k=1,score=False):
  if score:
    similar_docs = index.similarity_search_with_score(query,k=k)
  else:
    similar_docs = index.similarity_search(query,k=k)
  return similar_docs
  query= "what is an artificial intellegence"
  similar_docs = get_similiar_docs(query)
  similar_docs
